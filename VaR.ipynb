# %%
from pyomo.environ import ConcreteModel, Var, Objective, Constraint, NonNegativeReals, minimize, SolverFactory
import pyomo.environ as pyo
import pandas as pd
import numpy as np
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
model =pyo.ConcreteModel()
model.iset=pyo.Set(initialize=range(1,4))
model.sset=pyo.Set(initialize=range(1,11))
model.C=pyo.Param(initialize=1000)
model.Q=pyo.Param(initialize=0.02)
model.M=pyo.Param(initialize=10000000)
model.p=pyo.Param(model.sset, default=0, initialize=0.1)
model.alpha=pyo.Param(initialize=0.2)
model.x=pyo.Var(model.iset, domain=pyo.NonNegativeReals)
model.binary = pyo.Var(model.sset, domain = pyo.Binary)
model.v=pyo.Var(domain = pyo.Reals)
df = pd.read_excel('Book1.xlsx')
df_new=df.copy()
df_new.index= range(1,11)
df_new
# Out:
#        1     2     3
# 1   0.05  0.10 -0.05
# 2  -0.05  0.10  0.15
# 3   0.10  0.10  0.20
# 4  -0.05 -0.15  0.10
# 5   0.07  0.05 -0.20
# 6  -0.10  0.20  0.10
# 7   0.15  0.05 -0.10
# 8  -0.15 -0.10 -0.10
# 9   0.05  0.10  0.05
# 10  0.05  0.05  0.05

# %%
data_dict = {}
for i, row in df_new.iterrows():
    for j, value in row.items():
        data_dict[(i, j)] = value
#تعریف آرایه برای مقادیر a 
model.a=pyo.Param(model.sset, model.iset, default=0, initialize=data_dict)

# %%
data_array = np.zeros((10,3))
for (x, y), value in data_dict.items():
    data_array[x-1, y-1] = value

#محاسبه میانگین
mean = np.mean(data_array, axis=0)
mean_df = pd.DataFrame(mean, columns=['Mean'], index=[1,2,3])
mean_df
# Out:
#     Mean
# 1  0.012
# 2  0.050
# 3  0.020

# %%
def rule_mean(model, i):
 return mean[i-1]
model.mean=pyo.Param(model.iset, initialize=rule_mean)

# %%
def constraint_rule(model, s):
    return (1/model.C)*sum(model.a[s, i] * model.x[i] for i in model.iset) >= model.v - (model.M * model.binary[s])
model.constraints = Constraint(model.sset, rule=constraint_rule)

# %%
model.obj = Objective(expr=model.v, sense=pyo.maximize)

# %%
def rule_const1(model):
 return sum(model.mean[i]*model.x[i] for i in model.iset) >= model.Q * model.C
model.const1 = pyo.Constraint(rule=rule_const1)

def rule_const2(model):
 return sum(model.x[i] for i in model.iset) == model.C
model.const2 = pyo.Constraint(rule=rule_const2)

def rule_const3(model):
    return sum(model.p[s]*model.binary[s] for s in model.sset) <= model.alpha 
model.const3= pyo.Constraint(rule=rule_const3)

# %%
# %reload_ext gams.magic

# %%
# %gams set i(*);

# %%
# %%gams
# set j;
# parameter p(i,j);
# parameter p2(i,j);

# %%
solver = SolverFactory('gams')
result = solver.solve(model, solver='BARON', keepfiles=True, tee=True, io_options={'solvelink': 2},add_options=['option optcr=0;'])
model.display()

x1_value = pyo.value(model.x[1])
x2_value = pyo.value(model.x[2])
x3_value=pyo.value(model.x[3])
objective_value = pyo.value(model.obj)

print(f"x1 = {x1_value}")
print(f"x2 = {x2_value}")
print(f"x3 = {x3_value}")
# Out:
# --- Job model.gms Start 08/06/24 13:53:44 47.3.0 125a0e22 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\47\gmsprmNT.txt
# --- GAMS Parameters defined
#     Input C:\Users\farim\AppData\Local\Temp\tmp0ztnfm4g\model.gms
#     Output C:\Users\farim\AppData\Local\Temp\tmp0ztnfm4g\output.lst
#     ScrDir C:\Users\farim\AppData\Local\Temp\tmp0ztnfm4g\225a\
#     SysDir C:\GAMS\47\
#     CurDir C:\Users\farim\AppData\Local\Temp\tmp0ztnfm4g\
#     LogOption 3
# Licensee: GAMS Demo, for EULA and demo limitations see   G240530/0001CB-GEN
#           https://www.gams.com/latest/docs/UG%5FLicense.html         DC0000
#           C:\GAMS\47\gamslice.txt
#           Demo license for demonstration and instructional purposes only
# Processor information: 1 socket(s), 4 core(s), and 8 thread(s) available
# GAMS 47.3.0   Copyright (C) 1987-2024 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(153) 2 Mb
# --- Starting execution: elapsed 0:00:00.012
# --- model.gms(67) 3 Mb
# --- Generating MIP model GAMS_MODEL
# --- model.gms(71) 3 Mb
# ---   14 rows  15 columns  68 non-zeroes
# ---   10 discrete-columns
# --- Range statistics (absolute non-zero finite values)
# --- RHS       [min, max] : [ 2.000E-01, 1.000E+03] - Zero values observed as well
# --- Bound     [min, max] : [ 1.000E+00, 1.000E+00] - Zero values observed as well
# --- Matrix    [min, max] : [ 5.000E-05, 1.000E+07]
# --- Executing BARON (Solvelink=2): elapsed 0:00:00.019
#
# GAMS/BARON       47.3.0 125a0e22 Jul 15, 2024          WEI x86 64bit/MS Window
#
# *** This solver runs with a demo license. No commercial use.
# ===========================================================================
#  BARON version 24.5.8. Built: WIN-64 Wed May 8 10:05:37 EDT 2024
#  Running on machine LAPTOP-0F7NRT3G
#
#  BARON is a product of The Optimization Firm.
#  For information on BARON, see https://minlp.com/about-baron
#
#  If you publish work using this software, please cite publications from
#  https://minlp.com/baron-publications, such as:
#
#  Kilinc, M. and N. V. Sahinidis, Exploiting integrality in the global
#  optimization of mixed-integer nonlinear programming problems in BARON,
#  Optimization Methods and Software, 33, 540-562, 2018.
# ===========================================================================
#  This BARON run may utilize the following subsolver(s)
#  For LP/MIP/QP: CLP/CBC, ILOG CPLEX
#  For NLP: MINOS, SNOPT, External NLP, IPOPT, FILTERSQP
# ===========================================================================
#  Doing local search
#  Solving bounding LP
#  Starting multi-start local search
#  Preprocessing found feasible solution with value 0.200000
#  Done with local search
# ===========================================================================
#   Iteration    Open nodes         Time (s)    Lower bound      Upper bound
#           1             0             0.05     0.200000         0.200000
#
#                          *** Normal completion ***
#
#  Wall clock time:                     0.41
#  Total CPU time used:                 0.05
#
#  Total no. of BaR iterations:       1
#  Best solution found at node:      -1
#  Max. no. of nodes in memory:       1
#
#  All done
# ===========================================================================
#
# Solution      = 0.2  best solution found during preprocessing
# Best possible = 0.2
# Absolute gap  = 0  optca = 1E-9
# Relative gap  = 0  optcr = 1E-9
#
# --- Reading solution for model GAMS_MODEL
# ***
# *** Solver did not provide marginals for model GAMS_MODEL
# ***
# --- Executing after solve: elapsed 0:00:01.140
# --- model.gms(74) 3 Mb
# --- model.gms(153) 4 Mb
# --- Putfile results C:\Users\farim\AppData\Local\Temp\tmp0ztnfm4g\results.dat
# --- Putfile statresults C:\Users\farim\AppData\Local\Temp\tmp0ztnfm4g\resultsstat.dat
# *** Status: Normal completion
# --- Job model.gms Stop 08/06/24 13:53:46 elapsed 0:00:01.142
#
# GAMS WORKING DIRECTORY: C:\Users\farim\AppData\Local\Temp\tmp0ztnfm4g
#
# Model unknown
#
#   Variables:
#     x : Size=3, Index=iset
#         Key : Lower : Value  : Upper : Fixed : Stale : Domain
#           1 :     0 :    0.0 :  None : False : False : NonNegativeReals
#           2 :     0 : 1000.0 :  None : False : False : NonNegativeReals
#           3 :     0 :    0.0 :  None : False : False : NonNegativeReals
#     binary : Size=10, Index=sset
#         Key : Lower : Value       : Upper : Fixed : Stale : Domain
#           1 :     0 :       1e-08 :     1 : False : False : Binary
#           2 :     0 :       1e-08 :     1 : False : False : Binary
#           3 :     0 :       1e-08 :     1 : False : False : Binary
#           4 :     0 :     3.5e-08 :     1 : False : False : Binary
#           5 :     0 :     1.5e-08 :     1 : False : False : Binary
#           6 :     0 :         0.0 :     1 : False : False : Binary
#           7 :     0 :     1.5e-08 :     1 : False : False : Binary
#           8 :     0 :       3e-08 :     1 : False : False : Binary
#           9 :     0 : 0.999999875 :     1 : False : False : Binary
#          10 :     0 :         1.0 :     1 : False : False : Binary
#     v : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :  None :   0.2 :  None : False : False :  Reals
#
#   Objectives:
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True :   0.2
#
#   Constraints:
#     constraints : Size=10
#         Key : Lower : Body                    : Upper
#           1 :  None :                     0.0 :   0.0
#           2 :  None :                     0.0 :   0.0
#           3 :  None :                     0.0 :   0.0
#           4 :  None : -2.7755575615628914e-17 :   0.0
#           5 :  None :  1.3877787807814457e-17 :   0.0
#           6 :  None :                     0.0 :   0.0
#           7 :  None :  1.3877787807814457e-17 :   0.0
#           8 :  None :  2.7755575615628914e-17 :   0.0
#           9 :  None :             -9999998.65 :   0.0
#          10 :  None :      -9999999.850000001 :   0.0
#     const1 : Size=1
#         Key  : Lower : Body              : Upper
#         None :  20.0 : 50.00000000000001 :  None
#     const2 : Size=1
#         Key  : Lower  : Body   : Upper
#         None : 1000.0 : 1000.0 : 1000.0
#     const3 : Size=1
#         Key  : Lower : Body : Upper
#         None :  None :  0.2 :   0.2
# x1 = 0.0
# x2 = 1000.0
# x3 = 0.0

# %%
model.pprint()
